# %% [markdown]
# Create variables of all Python primitive data types. Print their: • Value  • Data Type  • Memory Address (id())

# %%
#integer number
from xmlrpc.client import Boolean


num1=10
print (num1)
print(type(num1))
print(id(num1))

#float number
num2=20.5
print (num2)
print(type(num2))
print(id(num2))

#complex number
num3= 2+3j
print (num3)
print(type(num3))
print(id(num3))

#Boolean value example
is_true= True   
print(is_true)
print(type(is_true))
print(id(is_true))

#string text example
text= "Hello, World!"
print(text)
print(type(text))
print(id(text))

#NoneType example
none_value= None
print(none_value)
print(type(none_value))
print(id(none_value))
# Out:
# 10
# <class 'int'>
# 140727293351112
# 20.5
# <class 'float'>
# 2153353639920
# (2+3j)
# <class 'complex'>
# 2153358267216
# True
# <class 'bool'>
# 140727292465584
# Hello, World!
# <class 'str'>
# 2153358506224
# None
# <class 'NoneType'>
# 140727292465648

# %% [markdown]
# 2. Create three variables - a = 15 - b = 4 • Addition  • Subtraction  • Multiplication  • Division  • Floor Division  • Modulus  • Exponent

# %%
#operators example
#1 addition example
a=10
b=5
sum= a+b
print(sum)

#2 subtraction example
a=100
b=5
res= a-b 
print(res)

#3 multiplication example
a=50
b=5
mul= a*b
print(mul)

#4 division example
a=20
b=5
div= a/b
print(div)

#5Floor division example
a=20
b=3
floor_div= a//b
print(floor_div)

#6 modulus example
a=20
b=3
modul=a%b
print(modul)

#7 exponent example
a=2 
b=3
exp= a**b
print(exp)
# Out:
# 15
# 95
# 250
# 4.0
# 6
# 2
# 8

# %% [markdown]
# 3. Create two variables: - x = "100" - y = 50 • Convert the variables so that you can perform arithmetic operations between them.

# %%
x='100'
y= 50
z=int(x)+y
print(z)
# Out:
# 150

# %% [markdown]
# 4. Predict the output before running the program, then verify.

# %%
a = 10 
b = 20 
print(a + b * 2) 
print((a + b) * 2) 
print(a ** 2 + b) 
print(a // 3) 
print(a / 3)
# Out:
# 50
# 60
# 120
# 3
# 3.3333333333333335

# %% [markdown]
# 5. Write a program to calculate electricity bill. Use variables for: • Units Consumed  • Cost per Unit  • Calculate total bill and GST (18%).

# %%
units = 100
cost = 8

bill = units * cost
gst = bill * 18 / 100
final = bill + gst

print(final)
# Out:
# 944.0

# %% [markdown]
# 6. Create a list of programming languages. - Check whether: • "Python" exists.  • "Java" does not exist.  • "C++" exists.  • Use Membership Operators.

# %%
languages = ["Python","C++","JavaScript"]
print("Python" in languages)
print("Java" not in languages)
print("C+" in languages)
# Out:
# True
# True
# False

# %% [markdown]
# 7. Write a program that converts: •  int → float  •  float → string  •  string → int  •  int → bool  •  bool → int

# %%
a = 10
print(float(a))      
b = 12.5
print(str(b))        
c = "20"
print(int(c))       
d = 5
print(bool(d))       
e = True
print(int(e))
# Out:
# 10.0
# 12.5
# 20
# True
# 1

# %% [markdown]
# 8. Predict the output.

# %%
a = 10
a += 5
a *= 2
a -= 8
a /= 4
print(a)
# Out:
# 5.5

# %% [markdown]
# 9. Predict the output.

# %%
print(5 == 5.0)
print(5 is 5.0)
# Out:
# True
# False
# <>:2: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\M TECH\AppData\Local\Temp\ipykernel_6140\186370292.py:2: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(5 is 5.0)

# %% [markdown]
# 10. Create a program that stores product information. Store: • Product Name  • Price  • Quantity  Calculate: • Total Cost  • GST (18%)  • Final Amount

# %%
product = "Pen"
price = 20
quantity = 5
total = price * quantity
gst = total * 18 / 100
final = total + gst
print( final)
# Out:
# 118.0

# %% [markdown]
# 11. Write a program that checks whether a person can register for a driving license. Conditions: • Age ≥ 18  • Indian Citizen

# %%
age = 20
citizen = "Indian"
print(age >= 18 and citizen == "Indian")
# Out:
# True

# %% [markdown]
# 12. Predict the output.

# %%
a = [10,20] 
b = a 
c = [10,20] 
print(a == b) 
print(a is b) 
print(a == c) 
print(a is c) 
print(id(a)) 
print(id(b)) 
print(id(c))
# Out:
# True
# True
# True
# False
# 2153358455424
# 2153358455424
# 2153358456256
