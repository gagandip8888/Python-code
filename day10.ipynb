# %% [markdown]
# 1. Write a program using a lambda function to find the square of each number in a list using map().

# %%
numbers = [2, 3, 4, 5]
result = list(map(lambda x: x * x, numbers))
print(result)
# Out:
# [4, 9, 16, 25]

# %% [markdown]
# 2. Write a program using a lambda function to convert all names in a list to uppercase using map().

# %%
names = ["gagan", "omkar", "sarthak", "prathmesh"]
result = list(map(lambda name: name.upper(), names))
print(result)
# Out:
# ['GAGAN', 'OMKAR', 'SARTHAK', 'PRATHMESH']

# %% [markdown]
# 3. Write a program using map() to calculate a 10% discount on a list of product prices.

# %%
prices = [100, 200, 500, 1000]
result = list(map(lambda price: price - (price * 10 / 100), prices))
print(result)
# Out:
# [90.0, 180.0, 450.0, 900.0]

# %% [markdown]
# 4. Write a program using filter() to extract all even numbers from a given list.

# %%
numbers = [10, 15, 22, 33, 40, 51, 60]
result = list(filter(lambda x: x % 2 == 0, numbers))
print(result)
# Out:
# [10, 22, 40, 60]

# %% [markdown]
# 5. Write a program using filter() to display all students who scored 35 or more marks.

# %%
students = {
    "Gagan": 80,
    "Omkar": 30,
    "Sarthak": 45,
    "Prathmesh": 25
}
result = dict(filter(lambda x: x[1] >= 35, students.items()))
print(result)
# Out:
# {'Gagan': 80, 'Sarthak': 45}

# %% [markdown]
# 6. Write a program using filter() to remove all empty strings from a list.

# %%
names = ["Gagan", "", "Omkar", "", "Sarthak"]
result = list(filter(lambda x: x != "", names))
print(result)
# Out:
# ['Gagan', 'Omkar', 'Sarthak']

# %% [markdown]
# 7. Write a program using map() to find the length of each string in a list.

# %%
names = ["Gagan", "Omkar", "Sarthak", "Prathmesh"]
result = list(map(lambda x: len(x), names))
print(result)
# Out:
# [5, 5, 7, 9]

# %% [markdown]
# 8. Write a program using reduce() to calculate the sum of all numbers in a list.

# %%
from functools import reduce
numbers = [10, 20, 30, 40]
result = reduce(lambda a, b: a + b, numbers)
print(result)
# Out:
# 100

# %% [markdown]
# 9. Given a list of employee salaries, use map() to increase each salary by 15%.

# %%
salaries = [20000, 25000, 30000, 40000]
result = list(map(lambda x: x + (x * 15 / 100), salaries))
print(result)
# Out:
# [23000.0, 28750.0, 34500.0, 46000.0]

# %% [markdown]
# 10. Given a list of integers, use filter() to display only the numbers that are divisible by both 3 and 5.

# %%
numbers = [10, 15, 20, 30, 45, 50, 60, 70]
result = list(filter(lambda x: x % 3 == 0 and x % 5 == 0, numbers))
print(result)
# Out:
# [15, 30, 45, 60]
