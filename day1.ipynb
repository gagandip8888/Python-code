# %% [markdown]
# Q1. Personal Profile Program Write a Python program to store the following information using variables and display it in a well-formatted way. • Name  • Age  • College Name  • City  • Course Name

# %%
Name= 'Gagandip pathare'
Age= 21
collage_name= 'sppu university'
city='pune'
course_name='Agentic ai'

print ("Name  :",Name)
print('Age   :',Age)
print('collage_name :',collage_name)
print('city name :',city)
print("Course Name :",course_name)
# Out:
# Name  : Gagandip pathare
# Age   : 21
# collage_name : sppu university
# city name : pune
# Course Name : Agentic ai

# %% [markdown]
# Q2. Student Report Create variables for the following student details and print them: • Student Name  • Roll Number  • Branch  • Percentage  • Passed (True/False)

# %%
Student_name='gagandip pathare'
Roll_no= 123456
Branch_name='Computer Science'
percentage= 90.5
Pass=True
print('Student Name:', Student_name)
print('Roll Number:', Roll_no)
print('Branch Name:', Branch_name)
print('Percentage:', percentage)
print('Pass:',Pass)
# Out:
# Student Name: gagandip pathare
# Roll Number: 123456
# Branch Name: Computer Science
# Percentage: 90.5
# Pass: True

# %% [markdown]
# Q3. Identifier Practice Create 10 valid identifiers related to a college management system (for example: student_name, roll_no, etc.) and assign appropriate values to them. Then print all the variables.

# %%
student_name='Sarthak gite'
roll_no= 123457
branch_name='Computer Science'
percentage= 85.0
Pass=False
Fees= 50000
Admition_year= 2022
Age= 20
passing_year=2025
Total_Fee_paid='All clear'

print('Student Name:', student_name)
print('Roll Number:', roll_no)
print('Branch Name:', branch_name)
print('percentage:',percentage)
print('Pass:',Pass )
print('Fees:',Fees )
print('Admission Year:',Admition_year )
print('Age:',Age )
print('Passing Year:',passing_year )
print('Total Fee Paid:',Total_Fee_paid )
# Out:
# Student Name: Sarthak gite
# Roll Number: 123457
# Branch Name: Computer Science
# percentage: 85.0
# Pass: False
# Fees: 50000
# Admission Year: 2022
# Age: 20
# Passing Year: 2025
# Total Fee Paid: All clear

# %% [markdown]
# Q4. Comments Practice Write a Python program that contains: • At least 3 single-line comments  • 1 multi-line comment  • A program that prints a short introduction about yourself.

# %%
#this is python practice for day 1
""" Hi my name is Gagandi pathare i am learning Agentic Ai  """
# Out:
# ' Hi my name is Gagandi pathare i am learning Agentic Ai  '

# %% [markdown]
# Q5. Correct the Errors Rewrite the following invalid variable names into valid Python identifiers and assign appropriate values to them. • 2student • student-name • student name • class • for • employee@id

# %%
Student2='Gagandip pathare'
student_name='Sarthak Gite'
Student_name='Prathmesh'
class_name='Agentic Ai'
for_count= 3
employee_id= 123456
print('Student 1:', Student2)
print('Student 2:', student_name)
print('Student 3:', Student_name)
print('Class Name:', class_name)
print('For Count:', for_count)
print('Employee ID:', employee_id)
# Out:
# Student 1: Gagandip pathare
# Student 2: Sarthak Gite
# Student 3: Prathmesh
# Class Name: Agentic Ai
# For Count: 3
# Employee ID: 123456
